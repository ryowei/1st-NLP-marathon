# %% [markdown]
# <a href="https://colab.research.google.com/github/ryowei/1st-NLP-marathon/blob/main/Day012_bag_of_words%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6d6e0e2-4f1c-4a82-be60-0efedc5ba04f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6d6e0e2-4f1c-4a82-be60-0efedc5ba04f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Restaurant_Reviews.tsv to Restaurant_Reviews.tsv

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %%
corpus
# Out:
# array(['Wow... Loved this place.', 'Crust is not good.',
#        'Not tasty and the texture was just nasty.',
#        'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#        'The selection on the menu was great and so were the prices.',
#        'Now I am getting angry and I want my damn pho.',
#        "Honeslty it didn't taste THAT fresh.)",
#        'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#        'The fries were great too.', 'A great touch.',
#        'Service was very prompt.', 'Would not go back.',
#        'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.',
#        'I tried the Cape Cod ravoli, chicken, with cranberry...mmmm!',
#        'I was disgusted because I was pretty sure that was human hair.',
#        'I was shocked because no signs indicate cash only.',
# ...

# %% [markdown]
# ### 從文本中取出所有單字

# %%
import nltk
nltk.download('punkt')
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = list(set(whole_words))
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    word_index[word] = n
    index_word[n] = word
    n = n+1

# %%
word_index
# Out:
# {'Wow': 5635,
#  '...': 12307,
#  'Loved': 659,
#  'this': 12524,
#  'place': 12559,
#  '.': 12675,
#  'Crust': 6,
#  'is': 12511,
#  'not': 12621,
#  'good': 12287,
#  'Not': 11837,
#  'tasty': 9618,
#  'and': 12631,
#  'the': 12673,
#  'texture': 12604,
#  'was': 12628,
#  'just': 12636,
#  'nasty': 12156,
#  'Stopped': 3567,
#  'by': 12664,
#  'during': 10854,
#  'late': 6630,
#  'May': 25,
#  'bank': 26,
#  'holiday': 27,
#  'off': 11404,
#  'Rick': 29,
#  'Steve': 30,
#  'recommendation': 8959,
#  'loved': 8829,
#  'it': 12669,
#  'The': 12625,
#  'selection': 8973,
#  'on': 11683,
#  'menu': 11961,
#  'great': 11263,
#  'so': 11622,
#  'were': 12607,
#  'prices': 9573,
#  'Now': 11015,
#  'I': 12648,
#  'am': 11726,
#  'getting': 12334,
#  'angry': 53,
#  'want': 12247,
#  'my': 12654,
#  'damn': 7472,
#  'pho': 2971,
#  'Honeslty': 61,
#  'did': 12245,
#  "n't": 12650,
#  'taste': 10068,
#  'THAT': 66,
#  'fresh': 12403,
#  ')': 12492,
#  'potatoes': 10625,
#  'like': 12325,
# ...

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: '.',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  19: '.',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  23: 'the',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  32: 'and',
#  33: 'loved',
#  34: 'it',
#  35: '.',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  39: 'the',
#  40: 'menu',
#  41: 'was',
#  42: 'great',
#  43: 'and',
#  44: 'so',
#  45: 'were',
#  46: 'the',
#  47: 'prices',
#  48: '.',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  54: 'and',
#  55: 'I',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  60: '.',
#  61: 'Honeslty',
#  62: 'it',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
# ...

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    '''創建一個vector'''
    word_index = []
    index_word = []
    n = 0
    for word in nltk.word_tokenize(sentence):
      if word in whole_words:
        word_index.append(n)
        n = n+1
    vector = word_index
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
